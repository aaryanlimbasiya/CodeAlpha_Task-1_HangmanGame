# %% [markdown]
# ## **BASIC HANGMAN GAME WITH SOME WORDS:**

# %%
import random

def choose_word():
    words = ["taskone","hangman","python", "internship", "codeaplha"]
    return random.choice(words)

def display_word(word, guessed_letters):
    display = ""
    for letter in word:
        if letter in guessed_letters:
            display += letter
        else:
            display += "_"
    return display

def hangman():
    max_attempts = 5
    guessed_letters = []
    word_to_guess = choose_word()
    attempts = 0

    print("\nWelcome to Hangman Game!!!")
    print("\nMax Attempts is Five Times Guess  a Word.")
    print(display_word(word_to_guess, guessed_letters))

    while "_" in display_word(word_to_guess, guessed_letters) and attempts < max_attempts:
        guess = input("Guess a letter: ").lower()

        if len(guess) != 1 or not guess.isalpha():
            print("\nPlease enter a valid single letter.")
            continue

        if guess in guessed_letters:
            print("\nYou've already guessed that letter. Try again.")
            continue

        guessed_letters.append(guess)

        if guess not in word_to_guess:
            attempts += 1
            print(f"\nIncorrect! Attempts left: {max_attempts - attempts}")

        print(display_word(word_to_guess, guessed_letters))

    if "_" not in display_word(word_to_guess, guessed_letters):
        print("\nCongratulations!!! You guessed the word and Won the game.")
    else:
        print(f"\nSorry, you ran out of attempts. The word was '{word_to_guess}'.")

if __name__ == "__main__":
    hangman()
# Out:
# Welcome to Hangman Game!!!
#
# Max Attempts is Five Times Guess  a Word.
# _______
# Guess a letter: t
# t______
# Guess a letter: a
# ta_____
# Guess a letter: s
# tas____
# Guess a letter: k
# task___
# Guess a letter: o
# tasko__
# Guess a letter: n
# taskon_
# Guess a letter: e
# taskone
#
# Congratulations!!! You guessed the word and Won the game.

# %% [markdown]
# ## **ALTERNATE WAY OF MAKING HANGMAN GAME WITH HANGMAN DIAGRAM:**

# %%
import random

HANGMAN = ['''
  +---+
  |   |
      |
      |
      |
      |
=========''', '''
  +---+
  |   |
  O   |
      |
      |
      |
=========''', '''
  +---+
  |   |
  O   |
  |   |
      |
      |
=========''', '''
  +---+
  |   |
  O   |
 /|   |
      |
      |
=========''', '''
  +---+
  |   |
  O   |
 /|\  |
      |
      |
=========''', '''
  +---+
  |   |
  O   |
 /|\  |
 /    |
      |
=========''', '''
  +---+
  |   |
  O   |
 /|\  |
 / \  |
      |
=========''']

words = ["mountain",
    "river",
    "table",
    "apple",
    "banana",
    "india",
    "america",
    "tree",
    "life",
    "computer",
    "grapes",
    "sea",
    "lake",
    "bench",
    "pen",
    "book",
    "key",
    "glass",
    "ice",
    "plane",
    "fine",
    "mumbai",
    "delhi",
    "chennai",
    "water",
    "food",
    "science",
    "machine",
    "python",
    "css",
    "bowl",
    "cat",
    "dog",
    "element",
    "golf",
    "horse",
    "junior",
    "king",
    "lemon",
    "nation",
    "orange",
    "price",
    "quin",
    "rose",
    "tie",
    "university",
    "word",
    "ray",
    "zimbabwe",
    "australia",
    "cricket"]

chances = 6

wordchoice = random.choice(words)
a = ['_' for k in range(len(wordchoice))]
GameOver = False

while not GameOver:
    userguess = input("Please Guess The Character: ")
    for i in range(len(wordchoice)):
        let = wordchoice[i]
        if let == userguess:
            a[i] = userguess
    print(a)

    if userguess not in wordchoice:
        print(HANGMAN[6-chances])
        chances -= 1
        print("Remaining Chances",chances)

        if chances == 0:
            GameOver = True
            print("Hard Luck !! You Lost The Game !!")

    if "_" not in a:
        GameOver = True
        print("Fabulous !! You Won The Game !!")
# Out:
# Please Guess The Character: a
# ['_', '_', 'a', '_', '_']
# Please Guess The Character: g
# ['g', '_', 'a', '_', '_']
# Please Guess The Character: f
# ['g', '_', 'a', '_', '_']
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# =========
# Remaining Chances 5
# Please Guess The Character: k
# ['g', '_', 'a', '_', '_']
#
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# =========
# Remaining Chances 4
# Please Guess The Character: t
# ['g', '_', 'a', '_', '_']
#
#   +---+
#   |   |
#   O   |
#   |   |
#       |
#       |
# =========
# Remaining Chances 3
# Please Guess The Character: x
# ['g', '_', 'a', '_', '_']
#
#   +---+
#   |   |
#   O   |
#  /|   |
#       |
#       |
# =========
# Remaining Chances 2
# Please Guess The Character: j
# ['g', '_', 'a', '_', '_']
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#       |
#       |
# =========
# Remaining Chances 1
# Please Guess The Character: o
# ['g', '_', 'a', '_', '_']
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#  /    |
#       |
# =========
# Remaining Chances 0
# Hard Luck !! You Lost The Game !!
